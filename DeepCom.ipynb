# %% [markdown]
# <a href="https://colab.research.google.com/github/satishphale/EMSE-DeepCom/blob/master/DeepCom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/xing-hu/EMSE-DeepCom.git
# Out:
# Cloning into 'EMSE-DeepCom'...
# remote: Enumerating objects: 479, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 479 (delta 37), reused 8 (delta 2), pack-reused 363
# Receiving objects: 100% (479/479), 653.08 MiB | 22.16 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# Checking out files: 100% (215/215), done.

# %%
# !ls
# %tensorflow_version 1.x
# Out:
# drive  EMSE-DeepCom  sample_data
# TensorFlow 1.x selected.

# %%
# !mkdir ../config
# !cp /content/EMSE-DeepCom/config.yaml /content/EMSE-DeepCom/default.yaml ../config

# %%
# !cp /content/drive/MyDrive/RP/data_RQ1-20210606T095042Z-001.zip ../emse-data
# !unzip ../emse-data/data_RQ1-20210606T095042Z-001.zip -d ../emse-data
# Out:
# Archive:  ../emse-data/data_RQ1-20210606T095042Z-001.zip
#   inflating: ../emse-data/data_RQ1/vocab.ast
#   inflating: ../emse-data/data_RQ1/vocab.nl
#   inflating: ../emse-data/data_RQ1/vocab.code
#   inflating: ../emse-data/data_RQ1/valid/valid.token.code
#   inflating: ../emse-data/data_RQ1/output/pre.out
#   inflating: ../emse-data/data_RQ1/output/sbt.out
#   inflating: ../emse-data/data_RQ1/valid/valid.token.ast
#   inflating: ../emse-data/data_RQ1/valid/valid.token.nl
#   inflating: ../emse-data/data_RQ1/output/hybrid.out
#   inflating: ../emse-data/data_RQ1/test/test.token.code
#   inflating: ../emse-data/data_RQ1/test/test.token.ast
#   inflating: ../emse-data/data_RQ1/test/test.token.nl
#   inflating: ../emse-data/data_RQ1/valid/valid_ast.json
#   inflating: ../emse-data/data_RQ1/train/train.token.nl
#   inflating: ../emse-data/data_RQ1/test/test_ast.json
#   inflating: ../emse-data/data_RQ1/train/train.token.code
#   inflating: ../emse-data/data_RQ1/train/train_ast.json
# ...

# %%
# !cp ../emse-data/data_RQ1/vocab.ast ../emse-data/data_RQ1/vocab.nl ../emse-data/data_RQ1/vocab.code ../emse-data/model/hybrid/data

# %%
# !cp -r ../emse-data/data_RQ1/train ../emse-data
# !cp -r ../emse-data/data_RQ1/test ../emse-data
# !cp -r ../emse-data/data_RQ1/valid ../emse-data
# !cp -r ../emse-data/data_RQ1/output ../emse-data

# %%
# !python3 EMSE-DeepCom/source\ code/__main__.py EMSE-DeepCom/config.yaml --train --save -v
# Out:
# WARNING:tensorflow:From /content/EMSE-DeepCom/source code/rnn.py:107: The name tf.nn.rnn_cell.RNNCell is deprecated. Please use tf.compat.v1.nn.rnn_cell.RNNCell instead.
#
# WARNING:tensorflow:From /content/EMSE-DeepCom/source code/models.py:25: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# 06/06 12:55:46 label: default
# 06/06 12:55:46 description:
#   default configuration
#   next line of description
#   last line
# 06/06 12:55:46 EMSE-DeepCom/source code/__main__.py EMSE-DeepCom/config.yaml --train --save -v
# fatal: not a git repository (or any of the parent directories): .git
# 06/06 12:55:46 tensorflow version: 1.15.2
# 06/06 12:55:46 program arguments
# 06/06 12:55:46   aggregation_method   'sum'
# 06/06 12:55:46   align_encoder_id     0
# 06/06 12:55:46   allow_growth         True
# 06/06 12:55:46   attention_type       'global'
# 06/06 12:55:46   attn_filter_length   0
# 06/06 12:55:46   attn_filters         0
# ...

# %%
# !python3 EMSE-DeepCom/source\ code/__main__.py EMSE-DeepCom/config.yaml --train -v
# Out:
# WARNING:tensorflow:From /content/EMSE-DeepCom/source code/rnn.py:107: The name tf.nn.rnn_cell.RNNCell is deprecated. Please use tf.compat.v1.nn.rnn_cell.RNNCell instead.
#
# WARNING:tensorflow:From /content/EMSE-DeepCom/source code/models.py:25: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# 06/06 13:39:30 label: default
# 06/06 13:39:30 description:
#   default configuration
#   next line of description
#   last line
# 06/06 13:39:30 EMSE-DeepCom/source code/__main__.py EMSE-DeepCom/config.yaml --train -v
# fatal: not a git repository (or any of the parent directories): .git
# 06/06 13:39:30 tensorflow version: 1.15.2
# 06/06 13:39:30 program arguments
# 06/06 13:39:30   aggregation_method   'sum'
# 06/06 13:39:30   align_encoder_id     0
# 06/06 13:39:30   allow_growth         True
# 06/06 13:39:30   attention_type       'global'
# 06/06 13:39:30   attn_filter_length   0
# 06/06 13:39:30   attn_filters         0
# ...
